# %% [markdown]
# # **Big Mart Sales Prediction**

# %% [markdown]
# ## **Background Context**

# %% [markdown]
# BigMart is facing stiff competition in the retail industry, with numerous competitors vying for market share. They have observed fluctuations in their sales and want to understand the underlying factors influencing these changes. BigMart aims to optimize their sales and profitability by identifying the key drivers that impact their product sales.
#
# #### Business Goals:
#
# 1. Sales Optimization: BigMart's primary objective is to optimize their sales across all stores and product categories. They want to identify the factors that significantly impact sales, such as product attributes, store location, promotions, pricing strategies, and seasonality.
#
# 2. Inventory Management: BigMart aims to improve their inventory management by accurately forecasting demand for different products. By understanding sales patterns, they can optimize their stock levels, reduce wastage, and ensure the availability of popular items.
#
# 3. Pricing Strategy: BigMart seeks insights into pricing strategies that will attract more customers and boost sales. They want to determine the optimal price points for their products and assess the impact of pricing on sales performance.
#
# 4. Decision-making: BigMart intends to make data-driven decisions based on insights and predictions. They want to leverage the power of analytics to inform their strategies, such as promotional campaigns, store locations, and product assortment.

# %% [markdown]
# ## **Start Comet Experiment**

# %% [markdown]
# ## Comet
#
# Comet is a platform and toolset designed for machine learning experimentation and collaboration. It provides a centralized place for managing and tracking machine learning experiments, allowing data scientists and researchers to easily log and monitor their experiments, track metrics, and compare different models and hyperparameters.
#
# Comet offers a range of features to facilitate experiment tracking, including the ability to log code versions, parameters, and dependencies, as well as track and visualize metrics, losses, and model performance over time. It supports integration with popular machine learning frameworks and libraries, enabling seamless logging of experiment data.
#
# With Comet, teams can collaborate effectively by sharing experiment results, insights, and visualizations. It allows for easy comparison of experiments and models, aiding in the decision-making process. Additionally, Comet provides tools for hyperparameter optimization and experiment management, helping streamline the iterative process of developing and improving machine learning models.
#
# Overall, Comet simplifies the process of managing and tracking machine learning experiments, promoting reproducibility, collaboration, and efficient experimentation in the field of machine learning and data science.

# %%
# !pip install comet_ml

# %%
from comet_ml import Experiment
          
experiment = Experiment(
  api_key = "kuXaW2Hqiu6QPtv3uwHurDO2d",
  project_name = "naidt-cohort3",
  workspace="abdulmalikadeyemo"
)
# Out:
# COMET WARNING: To get all data logged automatically, import comet_ml before the following modules: xgboost, sklearn.
# COMET WARNING: As you are running in a Jupyter environment, you will need to call `experiment.end()` when finished to ensure all metrics and code are logged before exiting.
# COMET INFO: Couldn't find a Git repository in 'C:\\Users\\OGTL_SD-0035\\Documents\\NCAIR\\NAIDT' nor in any parent directory. Set `COMET_GIT_DIRECTORY` if your Git Repository is elsewhere.
# COMET INFO: Experiment is live on comet.com https://www.comet.com/abdulmalikadeyemo/naidt-cohort3/54a0ac107ee642c587c50e0cc930b936

# %% [markdown]
# <a id="cont"></a>
#
# ## Table of Contents
#
# <a href=#one>1. Importing Packages</a>
#
# <a href=#two>2. Data Collection and Description</a>
#
# <a href=#three>3. Loading Data </a>
#
# <a href=#four>4. Data Cleaning</a>
#
# <a href=#five>5. Exploratory Data Analysis (EDA)</a>
#
# <a href=#six>6. Feature Selection and Engineering </a>
#
# <a href=#seven>7. Modeling </a>
#
# <a href=#eight>8. Model Evaluation and Selection</a>
#
# <a href=#nine>9. Model Hyper-Parameter Tuning</a>
#
# <a href=#ten>10. Model Explanations</a>

# %% [markdown]
#  <a id="one"></a>
# ## 1. Importing Packages
# <a href=#cont>Back to Table of Contents</a>
#
# ---
#
# | ⚡ Description: Importing Packages ⚡ |
# | :--------------------------- |
# #### **Libraries for data loading, data manipulation, and data visualization**
#
# - **NumPy (`np`)**: A library for numerical computing in Python, providing support for large, multi-dimensional arrays and matrices. It offers a wide range of mathematical functions and operations for efficient data manipulation.
#
# - **Pandas (`pd`)**: A powerful library for data manipulation and analysis. It provides data structures such as DataFrames for organizing and analyzing structured data. Pandas offers various functions for reading and writing data, handling missing values, merging datasets, and performing data transformations.
#
# - **Matplotlib.pyplot (`plt`)**: A widely-used plotting library in Python that provides a flexible and comprehensive set of functions for creating visualizations. It offers various types of plots, including line plots, scatter plots, bar plots, histograms, and more.
#
# - **Seaborn (`sns`)**: A higher-level data visualization library built on top of Matplotlib. Seaborn simplifies the process of creating attractive statistical graphics by providing convenient functions for visualizing relationships between variables and creating informative plots.
#
# #### **Libraries for data preparation**
#
# - **Statsmodels.formula.api (`ols`)**: A library that provides a formula interface for specifying and estimating statistical models. It includes functionality for performing ordinary least squares (OLS) regression, which is useful for analyzing the relationship between a dependent variable and one or more independent variables.
#
# - **Scipy.stats (`pearsonr`)**: A module within the SciPy library that offers a wide range of statistical functions. The `pearsonr` function specifically computes the Pearson correlation coefficient and the p-value to measure the linear relationship between two variables.
#
# - **Sklearn.model_selection (`cross_val_score`, `train_test_split`, `RandomizedSearchCV`)**: Scikit-learn is a popular machine learning library in Python. The `cross_val_score` function is used for evaluating model performance using cross-validation. The `train_test_split` function is used to split a dataset into training and testing sets. The `RandomizedSearchCV` class performs randomized search over specified parameter values for hyperparameter tuning.
#
# - **Sklearn.metrics (`mean_squared_error`, `r2_score`)**: Scikit-learn provides various metrics for evaluating the performance of regression models. `mean_squared_error` calculates the mean squared error between predicted and true values, while `r2_score` computes the coefficient of determination, which indicates the proportion of variance explained by the model.
#
# - **Sklearn.preprocessing (`StandardScaler`)**: Scikit-learn offers preprocessing techniques to transform and scale data. The `StandardScaler` class is used for standardizing features by removing the mean and scaling to unit variance, which is particularly useful for models that assume normally distributed features.
#
# #### **Libraries for model building**
#
# - **XGBoost (`XGBRegressor`)**: XGBoost is an optimized gradient boosting framework that delivers high-performance models. The `XGBRegressor` class provides an implementation of the XGBoost algorithm for regression problems.
#
# - **Sklearn.ensemble (`GradientBoostingRegressor`, `RandomForestRegressor`)**: Scikit-learn's `GradientBoostingRegressor` class implements gradient boosting, a powerful ensemble method that combines multiple weak models to create a strong predictive model. The `RandomForestRegressor` class builds a random forest model, which is an ensemble of decision trees.
#
# - **Sklearn.svm (`SVR`)**: Scikit-learn's `SVR` class is used for Support Vector Regression, which uses support vector machines to perform regression tasks. It aims to find a hyperplane that best fits the training data, maximizing the margin while allowing for some error.
#
# - **Sklearn.linear_model (`Lasso`, `ElasticNet`, `SGDRegressor`, `BayesianRidge`)**: Scikit-learn provides various linear models for regression tasks. The `Lasso` and `ElasticNet` models perform regularization by adding a penalty term to the loss function. `SGDRegressor` implements linear regression using stochastic gradient descent. `BayesianRidge` uses Bayesian inference to estimate the parameters of a linear regression model.
#
# - **CatBoost (`CatBoostRegressor`)**: CatBoost is a gradient boosting library that supports categorical features and provides robust handling of missing values. The `CatBoostRegressor` class is used for regression tasks and offers high-performance boosting algorithms.
#
# - **Sklearn.kernel_ridge (`KernelRidge`)**: Scikit-learn's `KernelRidge` class combines ridge regression with the kernel trick, allowing for nonlinear relationships between features and the target variable. It uses the kernel function to map the data to a higher-dimensional space.

# %%
# Libraries for data loading, data manipulation and data visulisation
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import rc
import seaborn as sns

# Libraries for data preparation 
from statsmodels.formula.api import ols
from scipy.stats import pearsonr
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import train_test_split, RandomizedSearchCV
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.preprocessing import LabelEncoder, OrdinalEncoder, OneHotEncoder, StandardScaler, MinMaxScaler

#Libraries for model building
#pip install xgboost
#pip install catboost
from xgboost import XGBRegressor
from catboost import CatBoostRegressor
from sklearn.ensemble import GradientBoostingRegressor, RandomForestRegressor
from sklearn.svm import SVR
from sklearn.linear_model import Lasso, ElasticNet, SGDRegressor, BayesianRidge
from sklearn.kernel_ridge import KernelRidge
# from lightgbm import LGBMRegressor
# Out:
# COMET ERROR: Heartbeat processing error

# %% [markdown]
# <a id="two"></a>
# ## 2. Data Collection and Description
# <a class="anchor" id="1.1"></a>
# <a href=#cont>Back to Table of Contents</a>
# ---

# %% [markdown]
# #### Data Collection
# This Data was sourced from [Kaggle](https://www.kaggle.com/datasets/shivan118/big-mart-sales-prediction-datasets)
#
# #### Data Description
#
# The data scientists at BigMart have collected 2013 sales data for 1559 products across 10 stores in different cities. Also, certain attributes of each product and store have been defined. The aim is to build a predictive model and predict the sales of each product at a particular outlet.
#
# Using this model, BigMart will try to understand the properties of products and outlets which play a key role in increasing sales.
#
# Please note that the data may have missing values as some stores might not report all the data due to technical glitches. Hence, it will be required to treat them accordingly.
#
# #### Data Dictionary
# We have a train (8523) and test (5681) data set, the train data set has both input and output variable(s). You need to predict the sales for the test data set.
#
# **Train file:**
# CSV containing the item outlet information with a sales value
#
# **Variable Description**
#
# - Item_Identifier ---- Unique product ID
# - Item_Weight ---- Weight of product
# - Item_Fat_Content ---- Whether the product is low fat or not
# - Item_Visibility ---- The % of the total display area of all products in a store allocated to the - - - particular product
# - Item_Type ---- The category to which the product belongs
# - Item_MRP ---- Maximum Retail Price (list price) of the product
# - Outlet_Identifier ---- Unique store ID
# - Outlet_Establishment_Year ---- The year in which the store was established
# - Outlet_Size ---- The size of the store in terms of ground area covered
# - Outlet_Location_Type ---- The type of city in which the store is located
# - Outlet_Type ---- Whether the outlet is just a grocery store or some sort of supermarket
# - Item_Outlet_Sales ---- sales of the product in t particular store. This is the outcome variable to be predicted.

# %% [markdown]
# <a id="three"></a>
# ## 3. Loading the Data
# <a class="anchor" id="1.1"></a>
# <a href=#cont>Back to Table of Contents</a>
#
# ---
#
# | ⚡ Description: Loading the data ⚡ |
# | :--------------------------- |
#
# ---

# %%
data = pd.read_csv('mart_data.csv')

# %%
data.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Identifier            8523 non-null   object
#  1   Item_Weight                7060 non-null   float64
#  2   Item_Fat_Content           8523 non-null   object
#  3   Item_Visibility            8523 non-null   float64
#  4   Item_Type                  8523 non-null   object
#  5   Item_MRP                   8523 non-null   float64
#  6   Outlet_Identifier          8523 non-null   object
#  7   Outlet_Establishment_Year  8523 non-null   int64
#  8   Outlet_Size                6113 non-null   object
#  9   Outlet_Location_Type       8523 non-null   object
#  10  Outlet_Type                8523 non-null   object
#  11  Item_Outlet_Sales          8523 non-null   float64
# dtypes: float64(4), int64(1), object(7)
# memory usage: 799.2+ KB

# %% [markdown]
# <a id="four"></a>
# ## 4. Data Cleaning
# <a class="anchor" id="1.1"></a>
# <a href=#cont>Back to Table of Contents</a>
#
# ---
#
# | ⚡ Description: Data Cleaning ⚡ |
# | :--------------------------- |
# ---

# %% [markdown]
# **Handling Missing Values**

# %% [markdown]
# Handling Numerical Features:
# - Handle the missing values using either the `mean or the median` of that feature (column)
# - You will generally use the `mean` with the exception of if there are outliers in your dataset, in which case you would use the `median`
# - Always check for the presence of outliers before handling missing values with the mean
# - You can check for outliers using the `Boxplot`
#
# Handling Categorical Features:
# - You handle missing values using `mode` of that feature
# - Based on the data description, check if there might be variations in the `mode` of a feature based on another feature in your data

# %% [markdown]
# **Check for Null Values**

# %%
data.isna().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                  1463
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  2410
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %% [markdown]
# **Handling missing values in the `Item_Weight` column**

# %%
# Get the Central of Tendency of Item_Weight

mean_ = data['Item_Weight'].mean()
median_ = data['Item_Weight'].median()
mode_ = data['Item_Weight'].mode()[0]

print(f"Mean of Item_Weight: {mean_}\nMedian of Item_Weight: {median_}\nMode of Item_Weight: {mode_}")
# Out:
# Mean of Item_Weight: 12.857645184135976
# Median of Item_Weight: 12.6
# Mode of Item_Weight: 12.15

# %%
# calculate the mean value of "Item_Weight" column
mean_item_weight = data['Item_Weight'].mean()

# filling the missing values in "Item_weight column" with "Mean" value
data['Item_Weight'].fillna(mean_item_weight, inplace=True)

# %%
data.isna().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                     0
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  2410
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %% [markdown]
# **Handling missing values in the `Outlet_Size` column**

# %%
data['Outlet_Size'].mode()[0]
# Out:
# 'Medium'

# %%
# calculate the mode value of "Item_Weight" column
mode_of_Outlet_size = data['Outlet_Size'].mode()[0]
mode_of_Outlet_size
# Out:
# 'Medium'

# %% [markdown]
# **Take note of any dependency with any other column**

# %%
data[['Outlet_Type', 'Outlet_Size']]
# Out:
#             Outlet_Type Outlet_Size
# 0     Supermarket Type1      Medium
# 1     Supermarket Type2      Medium
# 2     Supermarket Type1      Medium
# 3         Grocery Store         NaN
# 4     Supermarket Type1        High
# ...                 ...         ...
# 8518  Supermarket Type1        High
# 8519  Supermarket Type1         NaN
# 8520  Supermarket Type1       Small
# 8521  Supermarket Type2      Medium
# 8522  Supermarket Type1       Small
#
# [8523 rows x 2 columns]

# %%
# Create a dataframe showing the mode of outlet size based of the outlet type
#, and show it
mode_of_Outlet_size = data.pivot_table(values='Outlet_Size', columns='Outlet_Type', 
                                       aggfunc=(lambda x: x.mode()[0]))

#Show the dataframe
mode_of_Outlet_size
# Out:
# Outlet_Type Grocery Store Supermarket Type1 Supermarket Type2  \
# Outlet_Size         Small             Small            Medium
#
# Outlet_Type Supermarket Type3
# Outlet_Size            Medium

# %%
data[data['Outlet_Size'].isnull()]
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 3              FDX07       19.200          Regular         0.000000
# 8              FDH17       16.200          Regular         0.016687
# 9              FDU28       19.200          Regular         0.094450
# 25             NCD06       13.000          Low Fat         0.099887
# 28             FDE51        5.925          Regular         0.161467
# ...              ...          ...              ...              ...
# 8502           NCH43        8.420          Low Fat         0.070712
# 8508           FDW31       11.350          Regular         0.043246
# 8509           FDG45        8.100          Low Fat         0.214306
# 8514           FDA01       15.000          Regular         0.054489
# 8519           FDS36        8.380          Regular         0.046982
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 3     Fruits and Vegetables  182.0950            OUT010
# ...

# %%
data['Outlet_Size'].isnull()
# Out:
# 0       False
# 1       False
# 2       False
# 3        True
# 4       False
#         ...
# 8518    False
# 8519     True
# 8520    False
# 8521    False
# 8522    False
# Name: Outlet_Size, Length: 8523, dtype: bool

# %%
data['Outlet_Type']
# Out:
# 0       Supermarket Type1
# 1       Supermarket Type2
# 2       Supermarket Type1
# 3           Grocery Store
# 4       Supermarket Type1
#               ...
# 8518    Supermarket Type1
# 8519    Supermarket Type1
# 8520    Supermarket Type1
# 8521    Supermarket Type2
# 8522    Supermarket Type1
# Name: Outlet_Type, Length: 8523, dtype: object

# %%
data.loc[miss_values,'Outlet_Type']
# Out:
# 3           Grocery Store
# 8       Supermarket Type1
# 9       Supermarket Type1
# 25      Supermarket Type1
# 28          Grocery Store
#               ...
# 8502    Supermarket Type1
# 8508    Supermarket Type1
# 8509        Grocery Store
# 8514    Supermarket Type1
# 8519    Supermarket Type1
# Name: Outlet_Type, Length: 2410, dtype: object

# %%
#Get the boolean version of the missing values
miss_values = data['Outlet_Size'].isnull()  

# filling the missing values in "Outlet_Size" column with Mode based on the Outlet type
data.loc[miss_values, 'Outlet_Size'] = data.loc[miss_values,'Outlet_Type'].apply(
                                            lambda x: mode_of_Outlet_size[x])

# %%
# checking for missing values
data.isnull().sum()
# Out:
# Item_Identifier              0
# Item_Weight                  0
# Item_Fat_Content             0
# Item_Visibility              0
# Item_Type                    0
# Item_MRP                     0
# Outlet_Identifier            0
# Outlet_Establishment_Year    0
# Outlet_Size                  0
# Outlet_Location_Type         0
# Outlet_Type                  0
# Item_Outlet_Sales            0
# dtype: int64

# %% [markdown]
# **Check for columns with string datatype**

# %%
data['Item_Identifier'].dtype
# Out:
# dtype('O')

# %%
# for i in data.columns:
#     dtype = data[i].dtype
#     if dtype == 'object':
#         print(i)
  
[i for i in data.columns if data[i].dtype == 'object' ]
# Out:
# ['Item_Identifier',
#  'Item_Fat_Content',
#  'Item_Type',
#  'Outlet_Identifier',
#  'Outlet_Size',
#  'Outlet_Location_Type',
#  'Outlet_Type']

# %%
str_col = [col for col in data.columns if data[col].dtype == 'object']
str_col
# Out:
# ['Item_Identifier',
#  'Item_Fat_Content',
#  'Item_Type',
#  'Outlet_Identifier',
#  'Outlet_Size',
#  'Outlet_Location_Type',
#  'Outlet_Type']

# %%
data[str_col]
# Out:
#      Item_Identifier Item_Fat_Content              Item_Type  \
# 0              FDA15          Low Fat                  Dairy
# 1              DRC01          Regular            Soft Drinks
# 2              FDN15          Low Fat                   Meat
# 3              FDX07          Regular  Fruits and Vegetables
# 4              NCD19          Low Fat              Household
# ...              ...              ...                    ...
# 8518           FDF22          Low Fat            Snack Foods
# 8519           FDS36          Regular           Baking Goods
# 8520           NCJ29          Low Fat     Health and Hygiene
# 8521           FDN46          Regular            Snack Foods
# 8522           DRG01          Low Fat            Soft Drinks
#
#      Outlet_Identifier Outlet_Size Outlet_Location_Type        Outlet_Type
# 0               OUT049      Medium               Tier 1  Supermarket Type1
# 1               OUT018      Medium               Tier 3  Supermarket Type2
# ...

# %%
data[['Item_Identifier','Item_Fat_Content','Item_Type','Outlet_Identifier',
      'Outlet_Size','Outlet_Location_Type','Outlet_Type']].head()
# Out:
#   Item_Identifier Item_Fat_Content              Item_Type Outlet_Identifier  \
# 0           FDA15          Low Fat                  Dairy            OUT049
# 1           DRC01          Regular            Soft Drinks            OUT018
# 2           FDN15          Low Fat                   Meat            OUT049
# 3           FDX07          Regular  Fruits and Vegetables            OUT010
# 4           NCD19          Low Fat              Household            OUT013
#
#   Outlet_Size Outlet_Location_Type        Outlet_Type
# 0      Medium               Tier 1  Supermarket Type1
# 1      Medium               Tier 3  Supermarket Type2
# 2      Medium               Tier 1  Supermarket Type1
# 3       Small               Tier 3      Grocery Store
# 4        High               Tier 3  Supermarket Type1

# %%
#Create a copy of the original dataframe

df = data.copy()

# %% [markdown]
# **Deal With Item_Identifier**

# %%
df['Item_Identifier'].nunique()
# Out:
# 1559

# %%
df['Item_Identifier'].value_counts()
# Out:
# FDW13    10
# FDG33    10
# NCY18     9
# FDD38     9
# DRE49     9
#          ..
# FDY43     1
# FDQ60     1
# FDO33     1
# DRF48     1
# FDC23     1
# Name: Item_Identifier, Length: 1559, dtype: int64

# %%
II_enc = LabelEncoder()

# %%
x = II_enc.fit_transform(df['Item_Identifier'])
x
# Out:
# array([ 156,    8,  662, ..., 1357,  681,   50])

# %%
II_enc.inverse_transform(x)
# Out:
# array(['FDA15', 'DRC01', 'FDN15', ..., 'NCJ29', 'FDN46', 'DRG01'],
#       dtype=object)

# %%
II_enc.transform(np.array(['FDA15']))
# Out:
# array([156])

# %%
#Create an encoder for Item_Identifier

II_enc = LabelEncoder()
df['Item_Identifier'] = II_enc.fit_transform(df['Item_Identifier'])

# %%
# df.head()

# %% [markdown]
# **Deal With Item_Fat_Content**

# %%
df['Item_Fat_Content'].nunique()
# Out:
# 5

# %%
#Check the count of each unique value present in the column
df['Item_Fat_Content'].value_counts()
# Out:
# Low Fat    5089
# Regular    2889
# LF          316
# reg         117
# low fat     112
# Name: Item_Fat_Content, dtype: int64

# %%
#Map the column to reflect the proper values

mapping = {'Low Fat':'Low Fat',
           'low fat':'Low Fat',
           'LF':'Low Fat',
           'Regular':'Regular', 
           'reg':'Regular'}
df['Item_Fat_Content'] = df['Item_Fat_Content'].map(mapping)

# %%
#Alternative approach

# df.replace({'Item_Fat_Content': {'low fat':'Low Fat','LF':'Low Fat', 'reg':'Regular'}}, inplace=True)

# %%
df['Item_Fat_Content'].value_counts()
# Out:
# Low Fat    5517
# Regular    3006
# Name: Item_Fat_Content, dtype: int64

# %%
#Create an encoder for Item_Fat_Content

IFC_enc = LabelEncoder()
df['Item_Fat_Content'] = IFC_enc.fit_transform(df['Item_Fat_Content'])

# %%
df['Item_Fat_Content']
# Out:
# 0       0
# 1       1
# 2       0
# 3       1
# 4       0
#        ..
# 8518    0
# 8519    1
# 8520    0
# 8521    1
# 8522    0
# Name: Item_Fat_Content, Length: 8523, dtype: int32

# %% [markdown]
# **Deal With Item_Type**

# %%
df['Item_Type'].value_counts()
# Out:
# Fruits and Vegetables    1232
# Snack Foods              1200
# Household                 910
# Frozen Foods              856
# Dairy                     682
# Canned                    649
# Baking Goods              648
# Health and Hygiene        520
# Soft Drinks               445
# Meat                      425
# Breads                    251
# Hard Drinks               214
# Others                    169
# Starchy Foods             148
# Breakfast                 110
# Seafood                    64
# Name: Item_Type, dtype: int64

# %%
#Create an encoder for Item_Type

IT_enc = LabelEncoder()
df['Item_Type'] = IT_enc.fit_transform(df['Item_Type'])

# %% [markdown]
# **Deal With Outlet_Identifier**

# %%
df['Outlet_Identifier'].value_counts()
# Out:
# OUT027    935
# OUT013    932
# OUT049    930
# OUT046    930
# OUT035    930
# OUT045    929
# OUT018    928
# OUT017    926
# OUT010    555
# OUT019    528
# Name: Outlet_Identifier, dtype: int64

# %%
#Extract the integers
df['Outlet_Identifier'] =  df['Outlet_Identifier'].str.extract('(\d+)')

#Convert the column to an integer data type
df['Outlet_Identifier'] = pd.to_numeric(df['Outlet_Identifier'])

# %%
df['Outlet_Identifier'].value_counts()
# Out:
# 27    935
# 13    932
# 49    930
# 46    930
# 35    930
# 45    929
# 18    928
# 17    926
# 10    555
# 19    528
# Name: Outlet_Identifier, dtype: int64

# %% [markdown]
# **Deal With Outlet_Size**

# %%
df['Outlet_Size'].value_counts()
# Out:
# Small     4798
# Medium    2793
# High       932
# Name: Outlet_Size, dtype: int64

# %%
OS_enc = OrdinalEncoder(categories = [['Small','Medium','High']])

df['Outlet_Size'] = OS_enc.fit_transform(df[['Outlet_Size']])

# %%
df['Outlet_Size'].value_counts()
# Out:
# 0.0    4798
# 1.0    2793
# 2.0     932
# Name: Outlet_Size, dtype: int64

# %% [markdown]
# **Deal With Outlet_Location_Type**

# %%
df['Outlet_Location_Type'].value_counts()
# Out:
# Tier 3    3350
# Tier 2    2785
# Tier 1    2388
# Name: Outlet_Location_Type, dtype: int64

# %%
#Extract the integers
df['Outlet_Location_Type'] =  df['Outlet_Location_Type'].str.extract('(\d+)')

#Convert the column to an integer data type
df['Outlet_Location_Type'] = pd.to_numeric(df['Outlet_Location_Type'])

# %%
df['Outlet_Location_Type'].value_counts()
# Out:
# 3    3350
# 2    2785
# 1    2388
# Name: Outlet_Location_Type, dtype: int64

# %% [markdown]
# **Deal With Outlet_Type**

# %%
df['Outlet_Type'].value_counts()
# Out:
# Supermarket Type1    5577
# Grocery Store        1083
# Supermarket Type3     935
# Supermarket Type2     928
# Name: Outlet_Type, dtype: int64

# %%
#Create an encoder for Outlet_Type

OT_enc = LabelEncoder()
df['Outlet_Type'] = OT_enc.fit_transform(df['Outlet_Type'])

# %%
df.head()
# Out:
#    Item_Identifier  Item_Weight  Item_Fat_Content  Item_Visibility  Item_Type  \
# 0              156         9.30                 0         0.016047          4
# 1                8         5.92                 1         0.019278         14
# 2              662        17.50                 0         0.016760         10
# 3             1121        19.20                 1         0.000000          6
# 4             1297         8.93                 0         0.000000          9
#
#    Item_MRP  Outlet_Identifier  Outlet_Establishment_Year  Outlet_Size  \
# 0  249.8092                 49                       1999          1.0
# 1   48.2692                 18                       2009          1.0
# 2  141.6180                 49                       1999          1.0
# 3  182.0950                 10                       1998          0.0
# 4   53.8614                 13                       1987          2.0
#
#    Outlet_Location_Type  Outlet_Type  Item_Outlet_Sales
# ...

# %% [markdown]
# ### Base Model Building

# %%
df.head()
# Out:
#    Item_Identifier  Item_Weight  Item_Fat_Content  Item_Visibility  Item_Type  \
# 0              156         9.30                 0         0.016047          4
# 1                8         5.92                 1         0.019278         14
# 2              662        17.50                 0         0.016760         10
# 3             1121        19.20                 1         0.000000          6
# 4             1297         8.93                 0         0.000000          9
#
#    Item_MRP  Outlet_Identifier  Outlet_Establishment_Year  Outlet_Size  \
# 0  249.8092                 49                       1999          1.0
# 1   48.2692                 18                       2009          1.0
# 2  141.6180                 49                       1999          1.0
# 3  182.0950                 10                       1998          0.0
# 4   53.8614                 13                       1987          2.0
#
#    Outlet_Location_Type  Outlet_Type  Item_Outlet_Sales
# ...

# %%
X = df.drop(columns=['Item_Outlet_Sales'], axis=1)

# %%
df.head()
# Out:
#    Item_Identifier  Item_Weight  Item_Fat_Content  Item_Visibility  Item_Type  \
# 0              156         9.30                 0         0.016047          4
# 1                8         5.92                 1         0.019278         14
# 2              662        17.50                 0         0.016760         10
# 3             1121        19.20                 1         0.000000          6
# 4             1297         8.93                 0         0.000000          9
#
#    Item_MRP  Outlet_Identifier  Outlet_Establishment_Year  Outlet_Size  \
# 0  249.8092                 49                       1999          1.0
# 1   48.2692                 18                       2009          1.0
# 2  141.6180                 49                       1999          1.0
# 3  182.0950                 10                       1998          0.0
# 4   53.8614                 13                       1987          2.0
#
#    Outlet_Location_Type  Outlet_Type  Item_Outlet_Sales
# ...

# %%
X = df.drop(columns=['Item_Outlet_Sales'], axis=1)

Y = df['Item_Outlet_Sales']

# %% [markdown]
# **Create a dictionary to store the names of the model and the actual model definition (or creation)**

# %%
clf = RandomForestRegressor()

# %%
clf.fit(X,Y)

# %%
models = {
          'random forest':RandomForestRegressor(random_state = 42),
          'gradient boosting': GradientBoostingRegressor(random_state = 42),
          'XGB':XGBRegressor(random_state = 42),
          'CatBoost': CatBoostRegressor(random_seed = 42, ),
          'support vector': SVR(),
          'lasso regression': Lasso(random_state = 42),
          'ElasticNet': ElasticNet(random_state = 42),
          'SGD Regressor': SGDRegressor(random_state = 42),
          'Bayesian Ridge': BayesianRidge(),
          'Kernel Ridge': KernelRidge()
#           'LGBMRegressor': LGBMRegressor(random_state = 42)
          }

# %% [markdown]
# **Define a function to perform cross validation on different models**

# %%
#Define a function to check the performace of different models 
def train_val_models(models,X, Y):
    
  #Create a 70 - 20 split of your data for the train and validation/test dataset
    X_train, X_val, Y_train, Y_val = train_test_split(X, Y, test_size=0.2, random_state=0, shuffle=False)

    train_scores = [] #A list to store all the training evaluation scores
    val_scores = [] #A list to store all the validation evaluation scores

    for name, model in models.items():
        model.fit( X_train, Y_train)
        Y_train_pred = model.predict(X_train)
        Y_val_pred = model.predict(X_val)
        train_score = r2_score(Y_train, Y_train_pred)
        val_score = r2_score(Y_val, Y_val_pred)
        train_scores.append(train_score)
        val_scores.append(val_score)
    
    score_df = pd.DataFrame([train_scores,val_scores], columns = list(models.keys())).transpose()
    score_df.rename(columns = {0:'Train', 1:'Valid'}, inplace = True)

    return score_df.sort_values(by = 'Valid', ascending = False)

# %%
score_df = train_val_models(models, X,Y)
# Out:
# Learning rate set to 0.055449
# 0:	learn: 1650.4932874	total: 2.45ms	remaining: 2.45s
# 1:	learn: 1604.6914633	total: 4.51ms	remaining: 2.25s
# 2:	learn: 1560.0458158	total: 6.84ms	remaining: 2.27s
# 3:	learn: 1518.2281087	total: 9.48ms	remaining: 2.36s
# 4:	learn: 1479.0593891	total: 12.2ms	remaining: 2.43s
# 5:	learn: 1443.9084838	total: 14.4ms	remaining: 2.38s
# 6:	learn: 1413.6966311	total: 16.4ms	remaining: 2.33s
# 7:	learn: 1383.7027856	total: 18.4ms	remaining: 2.29s
# 8:	learn: 1355.9776875	total: 20.5ms	remaining: 2.25s
# 9:	learn: 1331.7029329	total: 23ms	remaining: 2.27s
# 10:	learn: 1308.1036770	total: 25.4ms	remaining: 2.28s
# 11:	learn: 1287.9760170	total: 28ms	remaining: 2.3s
# 12:	learn: 1267.6428612	total: 30.1ms	remaining: 2.29s
# 13:	learn: 1249.8927438	total: 32.2ms	remaining: 2.27s
# 14:	learn: 1234.5540154	total: 34.3ms	remaining: 2.25s
# 15:	learn: 1221.0199006	total: 36.4ms	remaining: 2.24s
# 16:	learn: 1208.2575835	total: 38.7ms	remaining: 2.24s
# ...

# %%
score_df
# Out:
#                           Train         Valid
# gradient boosting  6.352213e-01  6.049254e-01
# CatBoost           7.706680e-01  5.791085e-01
# random forest      9.380332e-01  5.685391e-01
# XGB                8.508294e-01  5.422929e-01
# Kernel Ridge       5.095015e-01  5.083176e-01
# lasso regression   5.093966e-01  5.082894e-01
# Bayesian Ridge     5.092927e-01  5.081001e-01
# ElasticNet         4.823108e-01  4.777548e-01
# support vector    -4.962392e-02 -4.266453e-02
# SGD Regressor     -2.985056e+23 -2.958683e+23

# %% [markdown]
# ## **Limitations of Train/Valid/Test Split and the Solution**

# %% [markdown]
# - Metric Score tends to change depending on how the data is splitted, which makes it unreliable in-terms of estimating the model(s) performance
#   - concretely, it provides a high variance estimate since changing which observations happen to be in the testing set can significantly change the testing performance
#
# - It is unpractical to perform the Train/Valid/Test split on small dataset

# %% [markdown]
# ### **Solution: Cross Validation**

# %% [markdown]
# **Understanding K-Fold Cross Validation**
#
# ![k-fold-validation.png](data:image/png;base64,...)

# %% [markdown]
# #### **Cross Validation Recommendations**
#
# 1. K can be any number, but K=10 is generally recommended
# 2. For classification problems, stratified sampling is recommended for creating the folds.
#   - Each response class should be represented with equal proportions in each of the K folds.
#   - scikit-learn's cross_val_score function does this by default

# %% [markdown]
# ## **Implementing Cross Validation**

# %%
from sklearn.model_selection import cross_val_score

# %%
#Create a dictionary to store the names of the model and the actual model definition (or creation)
models = {
          'random forest':RandomForestRegressor(random_state = 42),
          'gradient boosting': GradientBoostingRegressor(random_state = 42),
          'XGB':XGBRegressor(random_state = 42),
          'CatBoost': CatBoostRegressor(random_seed = 42, ),
          'lasso regression': Lasso(random_state = 42),
          'Bayesian Ridge': BayesianRidge()
#           'LGBMRegressor': LGBMRegressor(random_state = 42)
          }

# %%
#Define a function to check the performace of different models 
def cross_val_models(model_dict, X, Y):
    
    cv_scores = [] #A list to store the mean performance of each model
    
    for name, model in model_dict.items():
        cv_score = cross_val_score(model, X, Y, cv=10, scoring='r2').mean()
        cv_scores.append(cv_score)

    score_df = pd.DataFrame([cv_scores], columns = list(model_dict.keys())).transpose()
    score_df.rename(columns = {0:'CV_Score'}, inplace = True)

    return score_df.sort_values(by = 'CV_Score', ascending = False)

# %%
score_df = cross_val_models(models, X, Y)
# Out:
# Learning rate set to 0.056491
# 0:	learn: 1650.0462503	total: 3.52ms	remaining: 3.52s
# 1:	learn: 1603.0702599	total: 5.95ms	remaining: 2.97s
# 2:	learn: 1557.4369142	total: 8.6ms	remaining: 2.86s
# 3:	learn: 1516.3880476	total: 11.3ms	remaining: 2.81s
# 4:	learn: 1478.1501365	total: 13.4ms	remaining: 2.67s
# 5:	learn: 1441.8488136	total: 16ms	remaining: 2.64s
# 6:	learn: 1408.5271092	total: 19.1ms	remaining: 2.71s
# 7:	learn: 1377.2130242	total: 21.8ms	remaining: 2.7s
# 8:	learn: 1351.1772214	total: 24.6ms	remaining: 2.7s
# 9:	learn: 1325.7115123	total: 27.4ms	remaining: 2.71s
# 10:	learn: 1302.3367008	total: 30.3ms	remaining: 2.73s
# 11:	learn: 1281.0135651	total: 33.4ms	remaining: 2.75s
# 12:	learn: 1261.1481209	total: 36.1ms	remaining: 2.74s
# 13:	learn: 1243.8602401	total: 38.5ms	remaining: 2.71s
# 14:	learn: 1226.9227379	total: 40.9ms	remaining: 2.68s
# 15:	learn: 1212.2017842	total: 43.6ms	remaining: 2.68s
# 16:	learn: 1198.8558585	total: 46.4ms	remaining: 2.68s
# ...

# %%
score_df
# Out:
#                    CV_Score
# gradient boosting  0.592439
# CatBoost           0.568081
# random forest      0.551324
# XGB                0.524857
# lasso regression   0.506438
# Bayesian Ridge     0.506358

# %% [markdown]
# <a id="five"></a>
# ## 5. Exploratory Data Analysis (EDA)
# <a class="anchor" id="1.1"></a>
# <a href=#cont>Back to Table of Contents</a>
#
# ---
#
# | ⚡ Description: Exploratory data analysis ⚡ |
# | :--------------------------- |
#
# ---
